# %% [markdown]
# This script finds the co-diversifying clades within Moeller et al. supplemental fasta by creates a phylogeny and selecting the subtrees that match the topology of figure 1.
#
# Inputs: fasta of all Bacteroidaceae seqs, ref_gyrb_gtdbtk Bacteroidales reference seqs (fna and faa)
#
# Outputs: fasta of just co-div seqs with lineage and clade labels

# %%
import pandas as pd
import os
from Bio import SeqIO
from Bio import Seq
from ete3 import Tree

# %%
os.chdir('/Volumes/AHN/captive_ape_microbiome')
outdir = 'results/gyrb/processing/moeller_sup'

# %% [markdown]
# ### Generate phylogeny

# %%
# %%bash
# outdir=results/gyrb/processing/moeller_sup
# ref_faa=results/gyrb/processing/ref_gyrb_gtdbtk/gyrb_fastas/gtdbtk_gyrb_Bt.faa
# ref_fna=results/gyrb/processing/ref_gyrb_gtdbtk/gyrb_fastas/gtdbtk_gyrb_Bt.fasta
#
# mkdir -pv $outdir
#
# #trim primer sequences
# cutadapt  -g CGGAGGTAARTTCGAYAAAGG  --overlap 21 -e .15 --discard-untrimmed  -o  $outdir/Bacteroidaceae.fna  data/gyrb/moeller_sup/Bacteroidaceae.fna
#
# #translate gyrb amplicon seqs
# transeq -frame 2 -sequence $outdir/Bacteroidaceae.fna  -outseq $outdir/Bacteroidaceae.faa
#
# #combine gyrb amplicon and ref seqs
# cat $ref_faa $outdir/Bacteroidaceae.faa > $outdir/Bacteroidaceae_ref.faa
# cat $ref_fna $outdir/Bacteroidaceae.fna > $outdir/Bacteroidaceae_ref.fna
#
# #align seqs
# mafft --auto --quiet $outdir/Bacteroidaceae_ref.faa > $outdir/Bacteroidaceae_ref.faa.aln
# tranalign -asequence  $outdir/Bacteroidaceae_ref.fna -bsequence $outdir/Bacteroidaceae_ref.faa.aln -outseq $outdir/Bacteroidaceae_ref.fna.aln
# Out:
# This is cutadapt 2.5 with Python 3.7.7
# Command line parameters: -g CGGAGGTAARTTCGAYAAAGG --overlap 21 -e .15 --discard-untrimmed -o results/gyrb/processing/moeller_sup/Bacteroidaceae.fna data/gyrb/moeller_sup/Bacteroidaceae.fna
# Processing reads on 1 core in single-end mode ...
# Finished in 0.46 s (638 us/read; 0.09 M reads/minute).
#
# === Summary ===
#
# Total reads processed:                     724
# Reads with adapters:                       724 (100.0%)
# Reads written (passing filters):           724 (100.0%)
#
# Total basepairs processed:       217,200 bp
# Total written (filtered):        200,991 bp (92.5%)
#
# === Adapter 1 ===
#
# Sequence: CGGAGGTAARTTCGAYAAAGG; Type: regular 5'; Length: 21; Trimmed: 724 times.
#
# No. of allowed errors:
# 0-5 bp: 0; 6-12 bp: 1; 13-19 bp: 2; 20-21 bp: 3
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 21	194	0.0	3	194
# 22	192	0.0	3	192
# 23	201	0.0	3	201
# 24	137	0.0	3	137
# Translate nucleic acid sequences
# Generate an alignment of nucleic coding regions from aligned proteins
# Error: Guide protein sequence Gorilla3374716_2 not found in nucleic sequence Gorilla3374716
# Error: Guide protein sequence Human3058374_2 not found in nucleic sequence Human3058374
# Error: Guide protein sequence Human9403092_2 not found in nucleic sequence Human9403092
# Error: Guide protein sequence Chimp10413648_2 not found in nucleic sequence Chimp10413648
# Error: Guide protein sequence Chimp10757854_2 not found in nucleic sequence Chimp10757854
# Error: Guide protein sequence Chimp10796222_2 not found in nucleic sequence Chimp10796222
# Error: Guide protein sequence Chimp11562025_2 not found in nucleic sequence Chimp11562025
# Error: Guide protein sequence Chimp3146215_2 not found in nucleic sequence Chimp3146215
# Error: Guide protein sequence Chimp8175258_2 not found in nucleic sequence Chimp8175258
# Error: Guide protein sequence Bonobo2919026_2 not found in nucleic sequence Bonobo2919026
# Error: Guide protein sequence Bonobo4229344_2 not found in nucleic sequence Bonobo4229344
# Error: Guide protein sequence Bonobo6282208_2 not found in nucleic sequence Bonobo6282208

# %%
#trim start of gyrB gene
def trim_aln(original_fasta,trim_fasta,start_pos,end_pos):
    with open(original_fasta) as original_fasta:
        with open(trim_fasta, 'w') as trim_fasta:
            records = SeqIO.parse(original_fasta, 'fasta')
            for record in records:
                record.seq = record.seq[start_pos:end_pos] 
                SeqIO.write(record, trim_fasta, 'fasta')
trim_aln(f'{outdir}/Bacteroidaceae_ref.fna.aln',f'{outdir}/Bacteroidaceae_ref.fna.aln.trim',429,2952)

# %%
# %%bash
# fasttree -nt -gtr < results/gyrb/processing/moeller_sup/Bacteroidaceae_ref.fna.aln.trim > results/gyrb/processing/moeller_sup/Bacteroidaceae_ref.fna.aln.trim.tre
# Out:
# FastTree Version 2.1.10 Double precision (No SSE3)
# Alignment: standard input
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Generalized Time-Reversible, CAT approximation with 20 rate categories
#       0.17 seconds: Top hits for    121 of   1529 seqs (at seed    100)
#       0.30 seconds: Top hits for    298 of   1529 seqs (at seed    200)
#       0.45 seconds: Top hits for    460 of   1529 seqs (at seed    300)
#       0.59 seconds: Top hits for    637 of   1529 seqs (at seed    400)
#       0.70 seconds: Top hits for    798 of   1529 seqs (at seed    500)
#       0.81 seconds: Top hits for    939 of   1529 seqs (at seed    600)
#       0.92 seconds: Top hits for   1091 of   1529 seqs (at seed    700)
#       1.06 seconds: Top hits for   1203 of   1529 seqs (at seed    900)
#       1.46 seconds: Joined    100 of   1526
#       1.81 seconds: Joined    200 of   1526
#       2.18 seconds: Joined    300 of   1526
#       2.53 seconds: Joined    400 of   1526
#       2.76 seconds: Joined    500 of   1526
#       3.08 seconds: Joined    600 of   1526
#       3.54 seconds: Joined    700 of   1526
#       4.13 seconds: Joined    800 of   1526
#       4.72 seconds: Joined    900 of   1526
#       5.27 seconds: Joined   1000 of   1526
#       5.77 seconds: Joined   1100 of   1526
#       6.36 seconds: Joined   1200 of   1526
#       7.01 seconds: Joined   1300 of   1526
#       7.43 seconds: Joined   1400 of   1526
#       8.00 seconds: Joined   1500 of   1526
# Initial topology in 8.05 seconds
# Refining topology: 42 rounds ME-NNIs, 2 rounds ME-SPRs, 21 rounds ML-NNIs
#       8.10 seconds: ME NNI round 1 of 42, 301 of 1527 splits, 79 changes (max delta 0.020)
#       8.21 seconds: ME NNI round 1 of 42, 1001 of 1527 splits, 312 changes (max delta 0.020)
#       8.33 seconds: ME NNI round 1 of 42, 1501 of 1527 splits, 405 changes (max delta 0.066)
#       8.44 seconds: ME NNI round 2 of 42, 501 of 1527 splits, 56 changes (max delta 0.021)
#       8.55 seconds: ME NNI round 2 of 42, 1101 of 1527 splits, 184 changes (max delta 0.100)
#       8.65 seconds: ME NNI round 3 of 42, 101 of 1527 splits, 1 changes (max delta 0.002)
#       8.76 seconds: ME NNI round 3 of 42, 801 of 1527 splits, 118 changes (max delta 0.023)
#       8.88 seconds: ME NNI round 4 of 42, 201 of 1527 splits, 17 changes (max delta 0.018)
#       8.98 seconds: ME NNI round 5 of 42, 1 of 1527 splits
#       9.10 seconds: ME NNI round 6 of 42, 1 of 1527 splits
#       9.21 seconds: ME NNI round 7 of 42, 101 of 1527 splits, 3 changes (max delta 0.003)
#       9.31 seconds: ME NNI round 10 of 42, 1 of 1527 splits
#       9.74 seconds: SPR round   1 of   2, 101 of 3056 nodes
#      10.13 seconds: SPR round   1 of   2, 201 of 3056 nodes
#      10.43 seconds: SPR round   1 of   2, 301 of 3056 nodes
#      10.77 seconds: SPR round   1 of   2, 401 of 3056 nodes
#      11.00 seconds: SPR round   1 of   2, 501 of 3056 nodes
#      11.38 seconds: SPR round   1 of   2, 601 of 3056 nodes
#      11.71 seconds: SPR round   1 of   2, 701 of 3056 nodes
#      11.89 seconds: SPR round   1 of   2, 801 of 3056 nodes
#      12.14 seconds: SPR round   1 of   2, 901 of 3056 nodes
#      12.49 seconds: SPR round   1 of   2, 1001 of 3056 nodes
#      12.73 seconds: SPR round   1 of   2, 1101 of 3056 nodes
#      13.04 seconds: SPR round   1 of   2, 1201 of 3056 nodes
#      13.30 seconds: SPR round   1 of   2, 1301 of 3056 nodes
#      13.60 seconds: SPR round   1 of   2, 1401 of 3056 nodes
#      13.84 seconds: SPR round   1 of   2, 1501 of 3056 nodes
#      14.03 seconds: SPR round   1 of   2, 1601 of 3056 nodes
#      14.43 seconds: SPR round   1 of   2, 1701 of 3056 nodes
#      14.70 seconds: SPR round   1 of   2, 1801 of 3056 nodes
#      14.91 seconds: SPR round   1 of   2, 1901 of 3056 nodes
#      15.22 seconds: SPR round   1 of   2, 2001 of 3056 nodes
#      15.61 seconds: SPR round   1 of   2, 2101 of 3056 nodes
#      15.97 seconds: SPR round   1 of   2, 2201 of 3056 nodes
#      16.39 seconds: SPR round   1 of   2, 2301 of 3056 nodes
#      16.77 seconds: SPR round   1 of   2, 2401 of 3056 nodes
#      16.93 seconds: SPR round   1 of   2, 2501 of 3056 nodes
#      17.08 seconds: SPR round   1 of   2, 2601 of 3056 nodes
#      17.39 seconds: SPR round   1 of   2, 2701 of 3056 nodes
#      17.75 seconds: SPR round   1 of   2, 2801 of 3056 nodes
#      18.12 seconds: SPR round   1 of   2, 2901 of 3056 nodes
#      18.48 seconds: SPR round   1 of   2, 3001 of 3056 nodes
#      18.67 seconds: ME NNI round 15 of 42, 1 of 1527 splits
#      18.77 seconds: ME NNI round 15 of 42, 601 of 1527 splits, 12 changes (max delta 0.006)
#      18.87 seconds: ME NNI round 15 of 42, 1201 of 1527 splits, 37 changes (max delta 0.006)
#      18.99 seconds: ME NNI round 16 of 42, 301 of 1527 splits, 4 changes (max delta 0.003)
#      19.10 seconds: ME NNI round 16 of 42, 1001 of 1527 splits, 17 changes (max delta 0.003)
#      19.22 seconds: ME NNI round 17 of 42, 101 of 1527 splits, 7 changes (max delta 0.006)
#      19.71 seconds: SPR round   2 of   2, 101 of 3056 nodes
#      20.07 seconds: SPR round   2 of   2, 201 of 3056 nodes
#      20.34 seconds: SPR round   2 of   2, 301 of 3056 nodes
#      20.74 seconds: SPR round   2 of   2, 401 of 3056 nodes
#      20.97 seconds: SPR round   2 of   2, 501 of 3056 nodes
#      21.29 seconds: SPR round   2 of   2, 601 of 3056 nodes
#      21.62 seconds: SPR round   2 of   2, 701 of 3056 nodes
#      21.77 seconds: SPR round   2 of   2, 801 of 3056 nodes
#      22.02 seconds: SPR round   2 of   2, 901 of 3056 nodes
#      22.34 seconds: SPR round   2 of   2, 1001 of 3056 nodes
#      22.56 seconds: SPR round   2 of   2, 1101 of 3056 nodes
#      22.86 seconds: SPR round   2 of   2, 1201 of 3056 nodes
#      23.10 seconds: SPR round   2 of   2, 1301 of 3056 nodes
#      23.37 seconds: SPR round   2 of   2, 1401 of 3056 nodes
#      23.59 seconds: SPR round   2 of   2, 1501 of 3056 nodes
#      23.76 seconds: SPR round   2 of   2, 1601 of 3056 nodes
#      24.16 seconds: SPR round   2 of   2, 1701 of 3056 nodes
#      24.42 seconds: SPR round   2 of   2, 1801 of 3056 nodes
#      24.62 seconds: SPR round   2 of   2, 1901 of 3056 nodes
#      24.89 seconds: SPR round   2 of   2, 2001 of 3056 nodes
#      25.36 seconds: SPR round   2 of   2, 2101 of 3056 nodes
#      25.85 seconds: SPR round   2 of   2, 2201 of 3056 nodes
#      26.24 seconds: SPR round   2 of   2, 2301 of 3056 nodes
#      26.61 seconds: SPR round   2 of   2, 2401 of 3056 nodes
#      26.77 seconds: SPR round   2 of   2, 2501 of 3056 nodes
#      26.91 seconds: SPR round   2 of   2, 2601 of 3056 nodes
#      27.21 seconds: SPR round   2 of   2, 2701 of 3056 nodes
#      27.59 seconds: SPR round   2 of   2, 2801 of 3056 nodes
#      27.95 seconds: SPR round   2 of   2, 2901 of 3056 nodes
#      28.28 seconds: SPR round   2 of   2, 3001 of 3056 nodes
#      28.49 seconds: ME NNI round 29 of 42, 1 of 1527 splits
#      28.60 seconds: ME NNI round 29 of 42, 601 of 1527 splits, 23 changes (max delta 0.009)
#      28.70 seconds: ME NNI round 29 of 42, 1201 of 1527 splits, 43 changes (max delta 0.014)
#      28.81 seconds: ME NNI round 30 of 42, 301 of 1527 splits, 11 changes (max delta 0.003)
#      28.92 seconds: ME NNI round 30 of 42, 1001 of 1527 splits, 31 changes (max delta 0.003)
#      29.04 seconds: ME NNI round 31 of 42, 101 of 1527 splits, 11 changes (max delta 0.011)
#      29.14 seconds: ME NNI round 35 of 42, 1 of 1527 splits
# Total branch-length 107.477 after 29.54 sec
#      29.58 seconds: ML Lengths 1 of 1527 splits
#      29.76 seconds: ML Lengths 101 of 1527 splits
#      29.94 seconds: ML Lengths 201 of 1527 splits
#      30.09 seconds: ML Lengths 301 of 1527 splits
#      30.25 seconds: ML Lengths 401 of 1527 splits
#      30.41 seconds: ML Lengths 501 of 1527 splits
#      30.59 seconds: ML Lengths 601 of 1527 splits
#      30.74 seconds: ML Lengths 701 of 1527 splits
#      30.90 seconds: ML Lengths 801 of 1527 splits
#      31.06 seconds: ML Lengths 901 of 1527 splits
#      31.22 seconds: ML Lengths 1001 of 1527 splits
#      31.39 seconds: ML Lengths 1101 of 1527 splits
#      31.56 seconds: ML Lengths 1201 of 1527 splits
#      31.71 seconds: ML Lengths 1301 of 1527 splits
#      31.87 seconds: ML Lengths 1401 of 1527 splits
#      32.04 seconds: ML Lengths 1501 of 1527 splits
#      32.62 seconds: ML NNI round 1 of 21, 101 of 1527 splits, 13 changes (max delta 11.412)
#      33.11 seconds: ML NNI round 1 of 21, 201 of 1527 splits, 48 changes (max delta 38.055)
#      33.64 seconds: ML NNI round 1 of 21, 301 of 1527 splits, 84 changes (max delta 74.275)
#      34.16 seconds: ML NNI round 1 of 21, 401 of 1527 splits, 106 changes (max delta 74.275)
#      34.69 seconds: ML NNI round 1 of 21, 501 of 1527 splits, 131 changes (max delta 74.275)
#      35.17 seconds: ML NNI round 1 of 21, 601 of 1527 splits, 151 changes (max delta 74.275)
#      35.73 seconds: ML NNI round 1 of 21, 701 of 1527 splits, 185 changes (max delta 74.275)
#      36.25 seconds: ML NNI round 1 of 21, 801 of 1527 splits, 229 changes (max delta 74.275)
#      36.79 seconds: ML NNI round 1 of 21, 901 of 1527 splits, 264 changes (max delta 74.275)
#      37.29 seconds: ML NNI round 1 of 21, 1001 of 1527 splits, 295 changes (max delta 74.275)
#      37.80 seconds: ML NNI round 1 of 21, 1101 of 1527 splits, 318 changes (max delta 74.275)
#      38.30 seconds: ML NNI round 1 of 21, 1201 of 1527 splits, 339 changes (max delta 74.275)
#      38.78 seconds: ML NNI round 1 of 21, 1301 of 1527 splits, 375 changes (max delta 74.275)
#      39.31 seconds: ML NNI round 1 of 21, 1401 of 1527 splits, 392 changes (max delta 74.275)
#      39.85 seconds: ML NNI round 1 of 21, 1501 of 1527 splits, 407 changes (max delta 74.275)
# ML-NNI round 1: LogLk = -964945.516 NNIs 414 max delta 74.27 Time 40.06
#      40.06 seconds: Optimizing GTR model, step 1 of 12
#      41.41 seconds: Optimizing GTR model, step 2 of 12
#      44.05 seconds: Optimizing GTR model, step 4 of 12
#      45.60 seconds: Optimizing GTR model, step 5 of 12
#      47.18 seconds: Optimizing GTR model, step 6 of 12
#      48.98 seconds: Optimizing GTR model, step 7 of 12
#      49.93 seconds: Optimizing GTR model, step 8 of 12
#      52.08 seconds: Optimizing GTR model, step 10 of 12
#      54.33 seconds: Optimizing GTR model, step 12 of 12
# GTR Frequencies: 0.2797 0.2408 0.2599 0.2196
# GTR rates(ac ag at cg ct gt) 1.8719 2.6568 1.7433 1.7273 5.5579 1.0000
#      55.51 seconds: ML Lengths 1 of 1527 splits
#      55.72 seconds: ML Lengths 101 of 1527 splits
#      55.91 seconds: ML Lengths 201 of 1527 splits
#      56.09 seconds: ML Lengths 301 of 1527 splits
#      56.24 seconds: ML Lengths 401 of 1527 splits
#      56.41 seconds: ML Lengths 501 of 1527 splits
#      56.57 seconds: ML Lengths 601 of 1527 splits
#      56.76 seconds: ML Lengths 701 of 1527 splits
#      56.91 seconds: ML Lengths 801 of 1527 splits
#      57.08 seconds: ML Lengths 901 of 1527 splits
#      57.26 seconds: ML Lengths 1001 of 1527 splits
#      57.42 seconds: ML Lengths 1101 of 1527 splits
#      57.60 seconds: ML Lengths 1201 of 1527 splits
#      57.77 seconds: ML Lengths 1301 of 1527 splits
#      57.94 seconds: ML Lengths 1401 of 1527 splits
#      58.12 seconds: ML Lengths 1501 of 1527 splits
#      58.30 seconds: Site likelihoods with rate category 1 of 20
#      58.43 seconds: Site likelihoods with rate category 2 of 20
#      58.55 seconds: Site likelihoods with rate category 3 of 20
#      58.68 seconds: Site likelihoods with rate category 4 of 20
#      58.80 seconds: Site likelihoods with rate category 5 of 20
#      58.92 seconds: Site likelihoods with rate category 6 of 20
#      59.05 seconds: Site likelihoods with rate category 7 of 20
#      59.17 seconds: Site likelihoods with rate category 8 of 20
#      59.29 seconds: Site likelihoods with rate category 9 of 20
#      59.41 seconds: Site likelihoods with rate category 10 of 20
#      59.54 seconds: Site likelihoods with rate category 11 of 20
#      59.66 seconds: Site likelihoods with rate category 12 of 20
#      59.78 seconds: Site likelihoods with rate category 13 of 20
#      59.90 seconds: Site likelihoods with rate category 14 of 20
#      60.02 seconds: Site likelihoods with rate category 15 of 20
#      60.14 seconds: Site likelihoods with rate category 16 of 20
#      60.27 seconds: Site likelihoods with rate category 17 of 20
#      60.39 seconds: Site likelihoods with rate category 18 of 20
#      60.52 seconds: Site likelihoods with rate category 19 of 20
#      60.65 seconds: Site likelihoods with rate category 20 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 1.143 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#      60.84 seconds: ML NNI round 2 of 21, 1 of 1527 splits
#      61.18 seconds: ML NNI round 2 of 21, 101 of 1527 splits, 11 changes (max delta 10.005)
#      61.57 seconds: ML NNI round 2 of 21, 201 of 1527 splits, 20 changes (max delta 24.550)
#      61.99 seconds: ML NNI round 2 of 21, 301 of 1527 splits, 39 changes (max delta 55.164)
#      62.61 seconds: ML NNI round 2 of 21, 401 of 1527 splits, 81 changes (max delta 55.164)
#      63.06 seconds: ML NNI round 2 of 21, 501 of 1527 splits, 102 changes (max delta 55.164)
#      63.61 seconds: ML NNI round 2 of 21, 601 of 1527 splits, 130 changes (max delta 55.164)
#      64.09 seconds: ML NNI round 2 of 21, 701 of 1527 splits, 145 changes (max delta 55.164)
#      64.66 seconds: ML NNI round 2 of 21, 801 of 1527 splits, 178 changes (max delta 55.164)
#      65.13 seconds: ML NNI round 2 of 21, 901 of 1527 splits, 201 changes (max delta 55.164)
#      65.52 seconds: ML NNI round 2 of 21, 1001 of 1527 splits, 212 changes (max delta 55.164)
#      66.15 seconds: ML NNI round 2 of 21, 1101 of 1527 splits, 251 changes (max delta 55.164)
#      66.64 seconds: ML NNI round 2 of 21, 1201 of 1527 splits, 283 changes (max delta 55.164)
#      67.04 seconds: ML NNI round 2 of 21, 1301 of 1527 splits, 300 changes (max delta 55.164)
#      67.62 seconds: ML NNI round 2 of 21, 1401 of 1527 splits, 335 changes (max delta 55.164)
#      68.09 seconds: ML NNI round 2 of 21, 1501 of 1527 splits, 350 changes (max delta 55.164)
# ML-NNI round 2: LogLk = -790966.537 NNIs 354 max delta 55.16 Time 68.20
#      68.20 seconds: ML NNI round 3 of 21, 1 of 1527 splits
#      68.70 seconds: ML NNI round 3 of 21, 101 of 1527 splits, 17 changes (max delta 2.033)
#      69.18 seconds: ML NNI round 3 of 21, 201 of 1527 splits, 40 changes (max delta 3.868)
#      69.71 seconds: ML NNI round 3 of 21, 301 of 1527 splits, 65 changes (max delta 6.541)
#      70.19 seconds: ML NNI round 3 of 21, 401 of 1527 splits, 79 changes (max delta 67.568)
#      70.73 seconds: ML NNI round 3 of 21, 501 of 1527 splits, 104 changes (max delta 67.568)
#      71.17 seconds: ML NNI round 3 of 21, 601 of 1527 splits, 116 changes (max delta 67.568)
#      71.78 seconds: ML NNI round 3 of 21, 701 of 1527 splits, 150 changes (max delta 67.568)
#      72.27 seconds: ML NNI round 3 of 21, 801 of 1527 splits, 179 changes (max delta 67.568)
#      72.74 seconds: ML NNI round 3 of 21, 901 of 1527 splits, 210 changes (max delta 67.568)
#      73.09 seconds: ML NNI round 3 of 21, 1001 of 1527 splits, 218 changes (max delta 67.568)
#      73.39 seconds: ML NNI round 3 of 21, 1101 of 1527 splits, 222 changes (max delta 67.568)
# ML-NNI round 3: LogLk = -790403.666 NNIs 223 max delta 67.57 Time 73.70
#      73.70 seconds: ML NNI round 4 of 21, 1 of 1527 splits
#      73.86 seconds: ML NNI round 4 of 21, 101 of 1527 splits, 1 changes (max delta 3.377)
#      74.36 seconds: ML NNI round 4 of 21, 201 of 1527 splits, 23 changes (max delta 50.905)
#      74.94 seconds: ML NNI round 4 of 21, 301 of 1527 splits, 51 changes (max delta 50.905)
#      75.38 seconds: ML NNI round 4 of 21, 401 of 1527 splits, 68 changes (max delta 50.905)
#      75.89 seconds: ML NNI round 4 of 21, 501 of 1527 splits, 87 changes (max delta 50.905)
#      76.26 seconds: ML NNI round 4 of 21, 601 of 1527 splits, 104 changes (max delta 50.905)
#      76.62 seconds: ML NNI round 4 of 21, 701 of 1527 splits, 133 changes (max delta 50.905)
#      76.91 seconds: ML NNI round 4 of 21, 801 of 1527 splits, 146 changes (max delta 50.905)
# ML-NNI round 4: LogLk = -790098.861 NNIs 154 max delta 50.90 Time 77.19
#      77.18 seconds: ML NNI round 5 of 21, 1 of 1527 splits
#      77.58 seconds: ML NNI round 5 of 21, 101 of 1527 splits, 14 changes (max delta 0.000)
#      78.09 seconds: ML NNI round 5 of 21, 201 of 1527 splits, 32 changes (max delta 24.697)
#      78.56 seconds: ML NNI round 5 of 21, 301 of 1527 splits, 53 changes (max delta 24.697)
#      78.86 seconds: ML NNI round 5 of 21, 401 of 1527 splits, 64 changes (max delta 24.697)
# ML-NNI round 5: LogLk = -790018.625 NNIs 66 max delta 24.70 Time 78.92
#      79.30 seconds: ML NNI round 6 of 21, 101 of 1527 splits, 16 changes (max delta 5.599)
#      79.54 seconds: ML NNI round 6 of 21, 201 of 1527 splits, 20 changes (max delta 5.599)
# ML-NNI round 6: LogLk = -789984.442 NNIs 21 max delta 6.03 Time 79.62
#      79.96 seconds: ML NNI round 7 of 21, 101 of 1527 splits, 12 changes (max delta 23.462)
# ML-NNI round 7: LogLk = -789939.288 NNIs 12 max delta 23.46 Time 80.08
#      80.08 seconds: ML NNI round 8 of 21, 1 of 1527 splits
# ML-NNI round 8: LogLk = -789905.985 NNIs 11 max delta 17.52 Time 80.33
#      80.33 seconds: ML NNI round 9 of 21, 1 of 1527 splits
# ML-NNI round 9: LogLk = -789903.460 NNIs 0 max delta 0.00 Time 80.45
# Turning off heuristics for final round of ML NNIs (converged)
#      80.44 seconds: ML NNI round 10 of 21, 1 of 1527 splits
#      81.27 seconds: ML NNI round 10 of 21, 101 of 1527 splits, 4 changes (max delta 5.016)
#      82.02 seconds: ML NNI round 10 of 21, 201 of 1527 splits, 13 changes (max delta 11.803)
#      82.74 seconds: ML NNI round 10 of 21, 301 of 1527 splits, 24 changes (max delta 11.803)
#      83.36 seconds: ML NNI round 10 of 21, 401 of 1527 splits, 41 changes (max delta 11.803)
#      84.11 seconds: ML NNI round 10 of 21, 501 of 1527 splits, 47 changes (max delta 11.803)
#      84.82 seconds: ML NNI round 10 of 21, 601 of 1527 splits, 73 changes (max delta 11.803)
#      85.52 seconds: ML NNI round 10 of 21, 701 of 1527 splits, 86 changes (max delta 11.803)
#      86.32 seconds: ML NNI round 10 of 21, 801 of 1527 splits, 109 changes (max delta 11.803)
#      87.07 seconds: ML NNI round 10 of 21, 901 of 1527 splits, 121 changes (max delta 11.803)
#      87.76 seconds: ML NNI round 10 of 21, 1001 of 1527 splits, 133 changes (max delta 11.803)
#      88.42 seconds: ML NNI round 10 of 21, 1101 of 1527 splits, 140 changes (max delta 11.803)
#      89.19 seconds: ML NNI round 10 of 21, 1201 of 1527 splits, 153 changes (max delta 11.803)
#      89.96 seconds: ML NNI round 10 of 21, 1301 of 1527 splits, 169 changes (max delta 11.803)
#      90.65 seconds: ML NNI round 10 of 21, 1401 of 1527 splits, 188 changes (max delta 11.803)
#      91.40 seconds: ML NNI round 10 of 21, 1501 of 1527 splits, 190 changes (max delta 11.803)
# ML-NNI round 10: LogLk = -788902.432 NNIs 190 max delta 11.80 Time 91.64 (final)
#      91.64 seconds: ML Lengths 1 of 1527 splits
#      91.84 seconds: ML Lengths 101 of 1527 splits
#      92.03 seconds: ML Lengths 201 of 1527 splits
#      92.22 seconds: ML Lengths 301 of 1527 splits
#      92.37 seconds: ML Lengths 401 of 1527 splits
#      92.55 seconds: ML Lengths 501 of 1527 splits
#      92.71 seconds: ML Lengths 601 of 1527 splits
#      92.88 seconds: ML Lengths 701 of 1527 splits
#      93.05 seconds: ML Lengths 801 of 1527 splits
#      93.23 seconds: ML Lengths 901 of 1527 splits
#      93.39 seconds: ML Lengths 1001 of 1527 splits
#      93.56 seconds: ML Lengths 1101 of 1527 splits
#      93.75 seconds: ML Lengths 1201 of 1527 splits
#      93.91 seconds: ML Lengths 1301 of 1527 splits
#      94.08 seconds: ML Lengths 1401 of 1527 splits
#      94.27 seconds: ML Lengths 1501 of 1527 splits
# Optimize all lengths: LogLk = -788880.884 Time 94.36
#      95.26 seconds: ML split tests for    100 of   1526 internal splits
#      96.17 seconds: ML split tests for    200 of   1526 internal splits
#      97.07 seconds: ML split tests for    300 of   1526 internal splits
#      97.94 seconds: ML split tests for    400 of   1526 internal splits
#      98.80 seconds: ML split tests for    500 of   1526 internal splits
#      99.67 seconds: ML split tests for    600 of   1526 internal splits
#     100.55 seconds: ML split tests for    700 of   1526 internal splits
#     101.44 seconds: ML split tests for    800 of   1526 internal splits
#     102.32 seconds: ML split tests for    900 of   1526 internal splits
#     103.23 seconds: ML split tests for   1000 of   1526 internal splits
#     104.09 seconds: ML split tests for   1100 of   1526 internal splits
#     104.95 seconds: ML split tests for   1200 of   1526 internal splits
#     105.94 seconds: ML split tests for   1300 of   1526 internal splits
#     106.85 seconds: ML split tests for   1400 of   1526 internal splits
#     107.73 seconds: ML split tests for   1500 of   1526 internal splits
# Total time: 107.98 seconds Unique: 1529/1607 Bad splits: 9/1526 Worst delta-LogLk 26.994

# %%
#view tree in figtree,  
#root based on outgroups 
#select clades with topology matching Figure 1 in Moeller et al. 
#save subtrees separately
#same sequence names separately, annotate with clade designations

# %%
in_tree = 'results/gyrb/processing/moeller_sup/Bacteroidaceae_ref.fna.aln.trim.tre'   
rooted_tree = 'results/gyrb/processing/moeller_sup/Bacteroidaceae_ref.fna.aln.trim.rooted.tre'  
Bt1_tree_file = 'results/gyrb/processing/moeller_sup/moeller_codiv_lin_Bt1.tree'  
Bt2_tree_file = 'results/gyrb/processing/moeller_sup/moeller_codiv_lin_Bt2.tree'  
Bt3_tree_file = 'results/gyrb/processing/moeller_sup/moeller_codiv_lin_Bt3.tree'  

tree = Tree(in_tree, format=0)
outgroup_taxa=[leaf.name for leaf in tree.get_leaves() if 
               'p__Gemmatimonadota' in leaf.name or 
               'o__Chlorobiales' in leaf.name or 
               'o__SJA-28' in leaf.name]
outgroup_MRCA = tree.get_common_ancestor(outgroup_taxa)
tree.set_outgroup(outgroup_MRCA)
tree.write(outfile=rooted_tree,format=2)

def get_lineage_ASVs(in_tree,listTaxa):    
    #makes sure we don't miss any ASVs that didn't match in the blast search \n"
    #but are descended from the MRCA of those that did\n"
    tree = Tree(in_tree, format=0)
    lineage_MRCA = tree.get_common_ancestor(listTaxa)
    linage_taxa = [x.name for x in lineage_MRCA.get_leaves()] 
    tree.prune(linage_taxa)
    return(tree)

def rename_taxa(lin_tree,listTaxa,cladeName):
    lineage_MRCA = lin_tree.get_common_ancestor(listTaxa)
    for taxa in lineage_MRCA.get_leaves():    
        taxa.name = taxa.name + ' ' + cladeName

Bt1_tree = get_lineage_ASVs(rooted_tree,['Gorilla5764570','Bonobo8808876'])
Bt1_taxa_oldnames = [leaf.name for leaf in Bt1_tree.get_leaves()]        
rename_taxa(Bt1_tree,['Gorilla5764570','Gorilla10693345'],'Bt1_clade1_gorilla')
rename_taxa(Bt1_tree,['Chimp6685161','Chimp5888147'],'Bt1_clade1_chimp')
rename_taxa(Bt1_tree,['Bonobo11821974','Bonobo8808876'],'Bt1_clade1_bonobo')
Bt1_taxa = [leaf.name for leaf in Bt1_tree.get_leaves()] 
Bt1_tree.write(outfile=Bt1_tree_file,format=2) 

Bt2_tree = get_lineage_ASVs(rooted_tree,['GCF_002933775.1p__Bacteroidotao__Bacteroidalesf__Bacteroidaceaes__Prevotella_sp002933775',
                                         'Bonobo5991239'])
Bt2_taxa_oldnames = [leaf.name for leaf in Bt2_tree.get_leaves()]        
rename_taxa(Bt2_tree,['Gorilla7248598','Gorilla1454159'],'Bt2_clade1_gorilla')
rename_taxa(Bt2_tree,['Chimp8269086','Chimp3094078'],'Bt2_clade1_chimp')
rename_taxa(Bt2_tree,['Bonobo11725448','Bonobo5991239'],'Bt2_clade1_bonobo')
rename_taxa(Bt2_tree,['Chimp1322981','Chimp3450568'],'Bt2_clade2_chimp')
rename_taxa(Bt2_tree,['Bonobo11213703','Bonobo6937590'],'Bt2_clade2_bonobo')
Bt2_taxa = [leaf.name for leaf in Bt2_tree.get_leaves()] 
Bt2_tree.write(outfile=Bt2_tree_file,format=2) 

Bt3_tree = get_lineage_ASVs(rooted_tree,['Human1330495','Bonobo4232320'])
Bt3_taxa_oldnames = [leaf.name for leaf in Bt3_tree.get_leaves()]        
rename_taxa(Bt3_tree,['Human1330495','Human12108738'],'Bt3_clade1_human')
rename_taxa(Bt3_tree,['Chimp2629519','Chimp873638'],'Bt3_clade1_chimp')
rename_taxa(Bt3_tree,['Bonobo6212174','Bonobo4232320'],'Bt3_clade1_bonobo')
Bt3_taxa = [leaf.name for leaf in Bt3_tree.get_leaves()] 
Bt3_tree.write(outfile=Bt3_tree_file,format=2)

# %%
codiv_taxa_oldnames = Bt1_taxa_oldnames + Bt2_taxa_oldnames + Bt3_taxa_oldnames
codiv_taxa = Bt1_taxa + Bt2_taxa + Bt3_taxa
codivDict = dict(zip(codiv_taxa_oldnames, codiv_taxa))
codivDF = pd.DataFrame(list(zip(codiv_taxa,codiv_taxa_oldnames)),columns=['codiv_taxa','codiv_taxa_oldnames'])
codivDF['moeller_seq'] = codivDF['codiv_taxa'].apply(lambda x: 'moeller' if 'p__Bacteroidota' not in x else 'ref')
codivDF = codivDF[codivDF['moeller_seq'] == 'moeller']
codivDF['codiv_clade'] = codivDF['codiv_taxa'].apply(lambda x: x.split(' ')[1])
codivDF['codiv_lineage'] = codivDF['codiv_clade'].apply(lambda x: x.split('_')[0])
codivDF['hostSpecies'] = codivDF['codiv_clade'].apply(lambda x: 'wild_'+x.split('_')[-1])
codivDF = codivDF[['codiv_taxa','codiv_clade','codiv_lineage','hostSpecies']]
codivDF.to_csv(f'{outdir}/moeller_codiv_HRclades.txt',index=False,sep='\t')
codivDF.head()
# Out:
#                            codiv_taxa         codiv_clade codiv_lineage  \
# 0   Gorilla5764570 Bt1_clade1_gorilla  Bt1_clade1_gorilla           Bt1
# 1   Gorilla3748318 Bt1_clade1_gorilla  Bt1_clade1_gorilla           Bt1
# 2  Gorilla12208365 Bt1_clade1_gorilla  Bt1_clade1_gorilla           Bt1
# 3   Gorilla4447500 Bt1_clade1_gorilla  Bt1_clade1_gorilla           Bt1
# 4   Gorilla8497213 Bt1_clade1_gorilla  Bt1_clade1_gorilla           Bt1
#
#     hostSpecies
# 0  wild_gorilla
# 1  wild_gorilla
# 2  wild_gorilla
# 3  wild_gorilla
# 4  wild_gorilla

# %%
with open(f'{outdir}/Bacteroidaceae.fna') as original: 
    with open(f'{outdir}/moeller_codiv_Bacteroidaceae.fna', 'w') as covid:
        records = SeqIO.parse(original, 'fasta')
        for record in records:
            if record.id in codiv_taxa_oldnames:
                print(record.id)
                record.id = codivDict[record.id]
                record.description = ''
                SeqIO.write(record, covid, 'fasta')
# Out:
# Gorilla10693345
# Gorilla10893151
# Gorilla12208365
# Gorilla1454159
# Gorilla3280123
# Gorilla3748318
# Gorilla4351822
# Gorilla4447500
# Gorilla5764570
# Gorilla6306341
# Gorilla7248598
# Gorilla7611566
# Gorilla7655534
# Gorilla8443136
# Gorilla8497213
# Gorilla8907336
# Gorilla9193943
# Gorilla9805772
# Human10045430
# Human10283488
# Human10889793
# Human10912985
# Human10912992
# Human12108738
# Human1330489
# Human1330495
# Human1781917
# Human237218
# Human2572122
# Human2935124
# Human3034958
# Human3367149
# Human3418197
# Human3961325
# Human4630891
# Human4639158
# Human4639166
# Human5110045
# Human5110051
# Human5465528
# Human5838232
# Human6390749
# Human6405675
# Human663970
# Human663977
# Human6649477
# Human6700665
# Human6700667
# Human7250453
# Human7563063
# Human7563070
# Human7859459
# Human8146958
# Human8295127
# Human8829943
# Human8842535
# Human9177678
# Human9518949
# Human9825266
# Chimp10218980
# Chimp1067447
# Chimp11049685
# Chimp11943611
# Chimp1322981
# Chimp1324508
# Chimp1493190
# Chimp1528180
# Chimp168543
# Chimp1862511
# Chimp2164238
# Chimp2506335
# Chimp2629519
# Chimp2757936
# Chimp2936652
# Chimp304514
# Chimp3094078
# Chimp3094087
# Chimp3162311
# Chimp3450568
# Chimp3450573
# Chimp3781815
# Chimp3970093
# Chimp4678997
# Chimp5183434
# Chimp5211526
# Chimp5888147
# Chimp665501
# Chimp6685161
# Chimp6973326
# Chimp6973327
# Chimp7736944
# Chimp7736952
# Chimp8269086
# Chimp828594
# Chimp873638
# Chimp8740623
# Chimp8780480
# Chimp9057405
# Chimp9057407
# Chimp9228565
# Chimp934253
# Chimp985651
# Chimp9859517
# Chimp9931019
# Chimp9931021
# Bonobo10034489
# Bonobo10057151
# Bonobo10352189
# Bonobo10513316
# Bonobo10520847
# Bonobo10609639
# Bonobo10623458
# Bonobo1078
# Bonobo11021063
# Bonobo11105611
# Bonobo11213703
# Bonobo11242356
# Bonobo11367003
# Bonobo11646549
# Bonobo11725448
# Bonobo11725461
# Bonobo11768907
# Bonobo11821974
# Bonobo12102095
# Bonobo12157978
# Bonobo12387329
# Bonobo1306358
# Bonobo1624513
# Bonobo1787673
# Bonobo1873599
# Bonobo1946453
# Bonobo2078905
# Bonobo2166737
# Bonobo2193524
# Bonobo229236
# Bonobo229241
# Bonobo23228
# Bonobo2366405
# Bonobo2450173
# Bonobo2645793
# Bonobo2919016
# Bonobo3176696
# Bonobo3311273
# Bonobo3371043
# Bonobo3681147
# Bonobo3793226
# Bonobo3971783
# Bonobo3994923
# Bonobo4076472
# Bonobo4186256
# Bonobo4208740
# Bonobo4208742
# Bonobo4214590
# Bonobo4214599
# Bonobo4232320
# Bonobo4255176
# Bonobo4255178
# Bonobo4400446
# Bonobo4469078
# Bonobo447600
# Bonobo4568548
# Bonobo4632650
# Bonobo4632659
# Bonobo4668782
# Bonobo4886707
# Bonobo4935167
# Bonobo4950863
# Bonobo5054462
# Bonobo5348599
# Bonobo5507217
# Bonobo5555405
# Bonobo5596313
# Bonobo5703402
# Bonobo5731561
# Bonobo5805938
# Bonobo5856903
# Bonobo5991239
# Bonobo6156032
# Bonobo6212174
# Bonobo6331470
# Bonobo6396279
# Bonobo6757245
# Bonobo6757253
# Bonobo6828899
# Bonobo6932003
# Bonobo6937590
# Bonobo7084162
# Bonobo7228450
# Bonobo742599
# Bonobo759069
# Bonobo7657683
# Bonobo781247
# Bonobo7895675
# Bonobo7932810
# Bonobo8148512
# Bonobo8213484
# Bonobo8808876
# Bonobo8808878
# Bonobo8821370
# Bonobo8827876
# Bonobo8964982
# Bonobo9176466
# Bonobo9375067
# Bonobo9719
# Bonobo972742
# Bonobo9728
# Bonobo9832770
# Bonobo9846630
